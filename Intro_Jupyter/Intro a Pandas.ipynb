# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.2'

# %%
rick_and_morty = pd.DataFrame(
    {
        "nombre": ["Rick", "Morty"],
        "apellidos": ["Sanchez", "Smith"],
        "edad": [60, 14]
    }
)

rick_and_morty
# Out:
#   nombre apellidos  edad
# 0   Rick   Sanchez    60
# 1  Morty     Smith    14

# %%
rick_and_morty = pd.DataFrame(
    [["Rick", "Sanchez", 60],
    ["Morty", "Smith", 14]]
    , columns=["nombre", "apellidos", "edad"]
)
rick_and_morty
# Out:
#   nombre apellidos  edad
# 0   Rick   Sanchez    60
# 1  Morty     Smith    14

# %%
type(rick_and_morty)
# Out:
# pandas.core.frame.DataFrame

# %%
# !head -n 5 ../../CursoDataScience/Intro_Jupyter/primary_results.csv
# Out:
# state,state_abbreviation,county,fips,party,candidate,votes,fraction_votes
# Alabama,AL,Autauga,1001.0,Democrat,Bernie Sanders,544,0.182
# Alabama,AL,Autauga,1001.0,Democrat,Hillary Clinton,2387,0.8
# Alabama,AL,Baldwin,1003.0,Democrat,Bernie Sanders,2694,0.32899999999999996
# Alabama,AL,Baldwin,1003.0,Democrat,Hillary Clinton,5290,0.647

# %%
votos = pd.read_csv("../../CursoDataScience/Intro_Jupyter/primary_results.csv")
votos
# Out:
#          state state_abbreviation          county        fips       party  \
# 0      Alabama                 AL         Autauga      1001.0    Democrat
# 1      Alabama                 AL         Autauga      1001.0    Democrat
# 2      Alabama                 AL         Baldwin      1003.0    Democrat
# 3      Alabama                 AL         Baldwin      1003.0    Democrat
# 4      Alabama                 AL         Barbour      1005.0    Democrat
# ...        ...                ...             ...         ...         ...
# 24606  Wyoming                 WY  Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
#
#              candidate  votes  fraction_votes
# ...

# %%
df = votos

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
df.tail()
# Out:
#          state state_abbreviation          county        fips       party  \
# 24606  Wyoming                 WY  Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY   Uinta-Lincoln  95600027.0  Republican
#
#           candidate  votes  fraction_votes
# 24606      Ted Cruz      0             0.0
# 24607  Donald Trump      0             0.0
# 24608   John Kasich      0             0.0
# 24609   Marco Rubio      0             0.0
# 24610      Ted Cruz     53             1.0

# %%
df.dtypes
# Out:
# state                  object
# state_abbreviation     object
# county                 object
# fips                  float64
# party                  object
# candidate              object
# votes                   int64
# fraction_votes        float64
# dtype: object

# %%
df.describe()
# Out:
#                fips          votes  fraction_votes
# count  2.451100e+04   24611.000000    24611.000000
# mean   2.667152e+07    2306.252773        0.304524
# std    4.200978e+07    9861.183572        0.231401
# min    1.001000e+03       0.000000        0.000000
# 25%    2.109100e+04      68.000000        0.094000
# 50%    4.208100e+04     358.000000        0.273000
# 75%    9.090012e+07    1375.000000        0.479000
# max    9.560004e+07  590502.000000        1.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=24611, step=1)

# %%
df.loc[1]
# Out:
# state                         Alabama
# state_abbreviation                 AL
# county                        Autauga
# fips                           1001.0
# party                        Democrat
# candidate             Hillary Clinton
# votes                            2387
# fraction_votes                    0.8
# Name: 1, dtype: object

# %%
df2 = df.set_index("county")

# %%
df2.head()
# Out:
#            state state_abbreviation    fips     party        candidate  votes  \
# county
# Autauga  Alabama                 AL  1001.0  Democrat   Bernie Sanders    544
# Autauga  Alabama                 AL  1001.0  Democrat  Hillary Clinton   2387
# Baldwin  Alabama                 AL  1003.0  Democrat   Bernie Sanders   2694
# Baldwin  Alabama                 AL  1003.0  Democrat  Hillary Clinton   5290
# Barbour  Alabama                 AL  1005.0  Democrat   Bernie Sanders    222
#
#          fraction_votes
# county
# Autauga           0.182
# Autauga           0.800
# Baldwin           0.329
# Baldwin           0.647
# Barbour           0.078

# %%
df2.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/data/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/data/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/data/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/data/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~/anaconda3/envs/data/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
df2.loc["Los Angeles"]
# Out:
#                   state state_abbreviation    fips       party  \
# county
# Los Angeles  California                 CA  6037.0    Democrat
# Los Angeles  California                 CA  6037.0    Democrat
# Los Angeles  California                 CA  6037.0  Republican
# Los Angeles  California                 CA  6037.0  Republican
# Los Angeles  California                 CA  6037.0  Republican
#
#                    candidate   votes  fraction_votes
# county
# Los Angeles   Bernie Sanders  434656           0.420
# Los Angeles  Hillary Clinton  590502           0.570
# Los Angeles     Donald Trump  179130           0.698
# Los Angeles      John Kasich   33559           0.131
# Los Angeles         Ted Cruz   30775           0.120

# %%
df2.iloc[1]
# Out:
# state                         Alabama
# state_abbreviation                 AL
# fips                           1001.0
# party                        Democrat
# candidate             Hillary Clinton
# votes                            2387
# fraction_votes                    0.8
# Name: Autauga, dtype: object

# %%
df['state']
# Out:
# 0        Alabama
# 1        Alabama
# 2        Alabama
# 3        Alabama
# 4        Alabama
#           ...
# 24606    Wyoming
# 24607    Wyoming
# 24608    Wyoming
# 24609    Wyoming
# 24610    Wyoming
# Name: state, Length: 24611, dtype: object

# %%
df.state
# Out:
# 0        Alabama
# 1        Alabama
# 2        Alabama
# 3        Alabama
# 4        Alabama
#           ...
# 24606    Wyoming
# 24607    Wyoming
# 24608    Wyoming
# 24609    Wyoming
# 24610    Wyoming
# Name: state, Length: 24611, dtype: object

# %%
df["shape"] = 1

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes  shape
# 0    544           0.182      1
# 1   2387           0.800      1
# 2   2694           0.329      1
# 3   5290           0.647      1
# 4    222           0.078      1

# %%
df.shape
# Out:
# (24611, 9)

# %%
df["shape"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 24606    1
# 24607    1
# 24608    1
# 24609    1
# 24610    1
# Name: shape, Length: 24611, dtype: int64

# %%
type(df.state)
# Out:
# pandas.core.series.Series

# %%
type(df[["state", "county"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[df.votes >= 590502]
# Out:
#            state state_abbreviation       county    fips     party  \
# 1386  California                 CA  Los Angeles  6037.0  Democrat
#
#             candidate   votes  fraction_votes  shape
# 1386  Hillary Clinton  590502            0.57      1

# %%
df[(df.county=="Manhattan")&(df.party=="Democrat")]
# Out:
#           state state_abbreviation     county     fips     party  \
# 15011  New York                 NY  Manhattan  36061.0  Democrat
# 15012  New York                 NY  Manhattan  36061.0  Democrat
#
#              candidate   votes  fraction_votes  shape
# 15011   Bernie Sanders   90227           0.337      1
# 15012  Hillary Clinton  177496           0.663      1

# %%
county = "Manhattan"

df.query("county == @county and party == 'Democrat'")
# Out:
#           state state_abbreviation     county     fips     party  \
# 15011  New York                 NY  Manhattan  36061.0  Democrat
# 15012  New York                 NY  Manhattan  36061.0  Democrat
#
#              candidate   votes  fraction_votes  shape
# 15011   Bernie Sanders   90227           0.337      1
# 15012  Hillary Clinton  177496           0.663      1

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes  shape
# 0    544           0.182      1
# 1   2387           0.800      1
# 2   2694           0.329      1
# 3   5290           0.647      1
# 4    222           0.078      1

# %%
df.sort_values(by="votes", ascending=False)
# Out:
#               state state_abbreviation        county        fips     party  \
# 1386     California                 CA   Los Angeles      6037.0  Democrat
# 1385     California                 CA   Los Angeles      6037.0  Democrat
# 4451       Illinois                 IL       Chicago  91700103.0  Democrat
# 4450       Illinois                 IL       Chicago  91700103.0  Democrat
# 4463       Illinois                 IL  Cook Suburbs  91700104.0  Democrat
# ...             ...                ...           ...         ...       ...
# 8476          Maine                 ME     Greenbush  92300181.0  Democrat
# 8474          Maine                 ME    Great Pond  92300180.0  Democrat
# 8473          Maine                 ME    Great Pond  92300180.0  Democrat
# 9637  Massachusetts                 MA       Holland  92500135.0  Democrat
# 8290          Maine                 ME   Castle Hill  92300087.0  Democrat
#
#             candidate   votes  fraction_votes  shape
# ...

# %%
df.groupby("state").votes.sum()
# Out:
# state
# Alabama           1223959
# Alaska              22469
# Arizona            834200
# Arkansas           605971
# California        4938197
# Colorado           121184
# Connecticut        531302
# Delaware           160416
# Florida           3940929
# Georgia           2032941
# Hawaii              46886
# Idaho              238989
# Illinois          3372537
# Indiana           1719291
# Iowa               326704
# Kansas             111296
# Kentucky           648885
# Louisiana          585781
# Maine                3415
# Maryland          1233272
# Massachusetts     1813320
# Michigan          2431111
# Mississippi        614200
# Missouri          1531672
# Montana            257516
# Nebraska           213691
# Nevada              86815
# New Hampshire      525966
# New Jersey        1321220
# New Mexico         309532
# New York          2686539
# North Carolina    2185747
# North Dakota          354
# Ohio              3204172
# Oklahoma           766123
# ...

# %%
df.groupby(["state", "party"]).votes.sum()
# Out:
# state          party
# Alabama        Democrat       386327
#                Republican     837632
# Alaska         Democrat          539
#                Republican      21930
# Arizona        Democrat       399097
#                               ...
# West Virginia  Republican     188138
# Wisconsin      Democrat      1000703
#                Republican    1072699
# Wyoming        Democrat          280
#                Republican        903
# Name: votes, Length: 95, dtype: int64

# %%
df["letra_estado"] = df.state_abbreviation.apply(lambda s: s[0])

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes  shape letra_estado
# 0    544           0.182      1            A
# 1   2387           0.800      1            A
# 2   2694           0.329      1            A
# 3   5290           0.647      1            A
# 4    222           0.078      1            A

# %%
df_pobreza = pd.read_csv("../../CursoDataScience/Intro_Jupyter/PovertyEstimates.csv")
df_pobreza.head()
# Out:
#    FIPStxt  PCTPOVALL_2015
# 0        0            14.7
# 1     1000            18.5
# 2     1001            12.7
# 3     1003            12.9
# 4     1005            32.0

# %%
df_merged = df.merge(df_pobreza, left_on="fips", right_on="FIPStxt")

# %%
df_merged.head()
# Out:
#      state state_abbreviation   county    fips       party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0    Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0    Democrat  Hillary Clinton
# 2  Alabama                 AL  Autauga  1001.0  Republican       Ben Carson
# 3  Alabama                 AL  Autauga  1001.0  Republican     Donald Trump
# 4  Alabama                 AL  Autauga  1001.0  Republican      John Kasich
#
#    votes  fraction_votes  shape letra_estado  FIPStxt  PCTPOVALL_2015
# 0    544           0.182      1            A     1001            12.7
# 1   2387           0.800      1            A     1001            12.7
# 2   1764           0.146      1            A     1001            12.7
# 3   5387           0.445      1            A     1001            12.7
# 4    421           0.035      1            A     1001            12.7

# %%
df_merged.to_excel("../../CursoDataScience/Intro_Jupyter/votos_pobreza.xls", sheet_name="datos")
# Out:
# <ipython-input-54-ab1cd12c463b>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df_merged.to_excel("../../CursoDataScience/Intro_Jupyter/votos_pobreza.xls", sheet_name="datos")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-ab1cd12c463b> in <module>
# ----> 1 df_merged.to_excel("../../CursoDataScience/Intro_Jupyter/votos_pobreza.xls", sheet_name="datos")
#
# ...
